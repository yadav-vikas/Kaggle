# %% [markdown]
# Over time, which states produce the most honey? Which produce the least? Which have experienced the most change in honey yield?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('honeyproduction.csv')
df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
states_production = df.groupby('state').totalprod.sum().reset_index()
f, ax = plt.subplots(figsize=(20, 14))
sns.barplot(x='state',y="totalprod", data=states_production, color="c")

# %%
states_production.max()
# Out:
# state                 WY
# totalprod    4.75085e+08
# dtype: object

# %%
states_stock = df.groupby('state').stocks.sum().reset_index()
f, ax = plt.subplots(figsize=(20, 14))
sns.barplot(x='state',y="stocks", data=states_stock, color="c")

# %%
state_year = df.groupby(['state','year','totalprod']).sum()
state_year.head()
# Out:
#                        numcol  yieldpercol    stocks  priceperlb  prodvalue
# state year totalprod
# AL    1998 1136000.0  16000.0           71  159000.0        0.72   818000.0
#       1999 1156000.0  17000.0           68  185000.0        0.56   647000.0
#       2000 1248000.0  16000.0           78  187000.0        0.59   736000.0
#       2001 1022000.0  14000.0           73  235000.0        0.72   736000.0
#       2002 1032000.0  12000.0           86  103000.0        1.18  1218000.0

# %%
#df.state.nunique().count()

# %%
state_AL =df.loc[df['state'] == 'AL']
state_AL
# Out:
#     state   numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue  \
# 0      AL  16000.0           71  1136000.0  159000.0        0.72   818000.0
# 43     AL  17000.0           68  1156000.0  185000.0        0.56   647000.0
# 86     AL  16000.0           78  1248000.0  187000.0        0.59   736000.0
# 129    AL  14000.0           73  1022000.0  235000.0        0.72   736000.0
# 173    AL  12000.0           86  1032000.0  103000.0        1.18  1218000.0
# 217    AL  13000.0           82  1066000.0   43000.0        1.24  1322000.0
# 261    AL  12000.0           87  1044000.0  282000.0        1.41  1472000.0
# 302    AL  13000.0           66   858000.0  266000.0        1.02   875000.0
# 343    AL  11000.0           72   792000.0  230000.0        1.21   958000.0
# 384    AL  11000.0           56   616000.0  209000.0        1.49   918000.0
# 425    AL   9000.0           66   594000.0  214000.0        1.90  1129000.0
# ...

# %%
plt.figure(figsize=(20,16))
state_AL.plot(grid=True)

# %%
all_states = df.state.unique()
all_states
# Out:
# array(['AL', 'AZ', 'AR', 'CA', 'CO', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN',
#        'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MI', 'MN', 'MS', 'MO', 'MT',
#        'NE', 'NV', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA',
#        'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'SC'],
#       dtype=object)

# %%
df.plot( subplots = True, grid = False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000208FE955408>,
# ...
#       dtype=object)

# %%
new_df =np.array(state_AL)
new_df
# Out:
# array([['AL', 16000.0, 71, 1136000.0, 159000.0, 0.72, 818000.0, 1998],
#        ['AL', 17000.0, 68, 1156000.0, 185000.0, 0.56, 647000.0, 1999],
#        ['AL', 16000.0, 78, 1248000.0, 187000.0, 0.59, 736000.0, 2000],
#        ['AL', 14000.0, 73, 1022000.0, 235000.0, 0.72, 736000.0, 2001],
#        ['AL', 12000.0, 86, 1032000.0, 103000.0, 1.18, 1218000.0, 2002],
#        ['AL', 13000.0, 82, 1066000.0, 43000.0, 1.24, 1322000.0, 2003],
#        ['AL', 12000.0, 87, 1044000.0, 282000.0, 1.41, 1472000.0, 2004],
#        ['AL', 13000.0, 66, 858000.0, 266000.0, 1.02, 875000.0, 2005],
#        ['AL', 11000.0, 72, 792000.0, 230000.0, 1.21, 958000.0, 2006],
#        ['AL', 11000.0, 56, 616000.0, 209000.0, 1.49, 918000.0, 2007],
#        ['AL', 9000.0, 66, 594000.0, 214000.0, 1.9, 1129000.0, 2008],
#        ['AL', 9000.0, 50, 450000.0, 68000.0, 1.86, 837000.0, 2009],
#        ['AL', 9000.0, 54, 486000.0, 73000.0, 2.4, 1166000.0, 2010],
# ...

# %%
sample = pd.DataFrame()
for i in all_states:
    sample = df.loc[df['state'] == i]
    plt.figure(figsize=(20,16))
    sample.plot(grid=True)
    plt.title(i)
# Out:
# C:\Users\Vikas\anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
# C:\Users\Vikas\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# ...

# %%
sample_2 = df.loc[df['state']=='AL'].groupby('year').totalprod
print(sample_2)

# %%
total_prod_dataframe = df.groupby(['totalprod']).year
total_prod_dataframe.head()
# Out:
# 0      1998
# 1      1998
# 2      1998
# 3      1998
# 4      1998
#        ...
# 621    2012
# 622    2012
# 623    2012
# 624    2012
# 625    2012
# Name: year, Length: 625, dtype: int64

# %%
production = pd.DataFrame([df.state,df.totalprod,df.year]).transpose()

production.head()
# Out:
#   state  totalprod  year
# 0    AL  1.136e+06  1998
# 1    AZ    3.3e+06  1998
# 2    AR  3.445e+06  1998
# 3    CA  3.735e+07  1998
# 4    CO  1.944e+06  1998

# %%
production.shape
# Out:
# (626, 3)

# %%
plt.figure(figsize=(20,5))
sns.catplot(data=production,x='state',y='totalprod',hue='state',kind='bar',height=5,aspect=3)

# %%
sns.color_palette("dark")
sns.relplot(x="year", y="totalprod", hue="state",
             estimator=None,
            kind="line", data=production,
           palette="bright")

# %%
sample = pd.DataFrame()
for i in all_states:
    sample = df.loc[df['state'] == i]
    plt.figure(figsize=(6,3))
    ax=plt.subplot(111)
    ax.plot(sample.totalprod)
    plt.title(i)
# Out:
# C:\Users\Vikas\anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
# C:\Users\Vikas\anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
# ...

# %% [markdown]
# Maximum production over the years

# %%
maximum_production = df.loc[df['totalprod'] == df.totalprod.max()]
maximum_production
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 532    ND  510000.0           91  46410000.0  12995000.0         1.5
#
#       prodvalue  year
# 532  69615000.0  2010

# %% [markdown]
# Minimum production over the years

# %%
minimum_production = df.loc[df['totalprod'] == df.totalprod.min()]
minimum_production
# Out:
#     state  numcol  yieldpercol  totalprod   stocks  priceperlb  prodvalue  \
# 233    MD  2000.0           42    84000.0  21000.0        1.93   162000.0
#
#      year
# 233  2003

# %% [markdown]
# During the perdion(1998-2012) the state "ND" has highest production over the years & state 'MD' has the lowest production at year 2003

# %% [markdown]
# the state 'SC' has the low production rate over the years
